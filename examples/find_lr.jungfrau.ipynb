# %%
# !pwd
# Out:
# /reg/data/ana03/scratch/cwang31/pf

# %%
# Run the notebook as if it's in the PROJECT directory
# %bookmark PROJ_ROOT /reg/data/ana03/scratch/cwang31/pf
# %cd -b PROJ_ROOT
# Out:
# (bookmark:PROJ_ROOT) -> /reg/data/ana03/scratch/cwang31/pf
# /reg/data/ana03/scratch/cwang31/pf

# %%
import os
import pickle
import numpy as np
import torch
import random
import tqdm
import time

# %%
import matplotlib              as mpl
import matplotlib.pyplot       as plt
import matplotlib.colors       as mcolors
import matplotlib.patches      as mpatches
import matplotlib.transforms   as mtransforms
import matplotlib.font_manager as font_manager
# %matplotlib inline

# %%
fl_pickle = "find_lr.pickle"
with open(fl_pickle, 'rb') as fh:
    data = pickle.load(fh)

# %%
len(data)
# Out:
# 100

# %%
data[0]
# Out:
# [-7.0, 0.13474099338054657, 0.13458587229251862, 0.13458587229251862]

# %%
x = [ datum[0] for datum in data ]
y = [ datum[1] for datum in data ]

# %%
fig = plt.figure(figsize = (10, 4))
plt.plot(x, y)
plt.gca().axvline(x = -4.25, color = 'r')
# plt.ylim(1e2,1.5e4)
# plt.gca().axvline(x=-3.3, color='r')

# %%
y
# Out:
# [0.13474099338054657]
